# %% [markdown]
# Install atau import library untuk vader sentiment analysis. Keterangan: google colabs untuk syntax di Linux terminal pake tanda seru

# %%
# Install vaderSentiment package for VADER
# !pip install vaderSentiment
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# Data processing
import pandas as pd
import numpy as np


# Import VADER sentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Import accuracy_score to check performance
from sklearn.metrics import accuracy_score

# Set a wider colwith
pd.set_option('display.max_colwidth', 1000) #pengaturan display

# %%
# Change directory
import os
os.chdir("./drive/My Drive/UTS/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-b0ed71bfb10c> in <cell line: 3>()
#       1 # Change directory
#       2 import os
# ----> 3 os.chdir("./drive/My Drive/UTS/")
#
# FileNotFoundError: [Errno 2] No such file or directory: './drive/My Drive/UTS/'

# %%
# Print out the current directory
# !pwd
# Out:
# /content/drive/MyDrive/UTS

# %%
# Read in data
fil_review = pd.read_csv('Reviews_Filter.csv', sep='\t', names=['review', 'label'])

# %%
# Take a look at the data
fil_review.head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         review  \
# ...

# %%
fil_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   review  15000 non-null  object
#  1   label   0 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 234.5+ KB

# %%
fil_review['label'].value_counts()
# Out:
# Series([], Name: label, dtype: int64)

# %%
# Example text
#text = 'GrabNGoInfo.com is a great machine learning tutorial website.'
text = 'The products are expensive and not good'

# VADER Sentiment
vader = SentimentIntensityAnalyzer() #inisilaisasi vader
vader_sentiment = vader.polarity_scores(text) #jalankan vader mengetahui polarity score untuk variabel text

# %%
vader_sentiment # print out hasil score nya
# Out:
# {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.3412}

# %%
vader_sentiment['compound'] # untuk print compund score nya saja
# Out:
# -0.3412

# %%
# Get sentiment score for each review
vader_sentiment = SentimentIntensityAnalyzer() #initialisasi
fil_review['scores_VADER'] = fil_review['review'].apply(lambda s: vader_sentiment.polarity_scores(s)['compound']) #mengambil compound score untuk masing2 review, lalu diletakan di kolom baru bernama 'SCORES_VADER'

# %%
fil_review.head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         review  \
# ...

# %%
# mengassign positive (1) atau negative (0) berdasar nilai scores_vader dan diletakan di kolom baru 'pred_VADER'
fil_review['pred_VADER'] = fil_review['scores_VADER'].apply(lambda x: 1 if x >=0 else 0)
fil_review.head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         review  \
# ...

# %%
# Compare Actual and Predicted
accuracy_score(fil_review['label'],fil_review['pred_VADER'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-bf15af5d2aa3> in <cell line: 2>()
#       1 # Compare Actual and Predicted
# ----> 2 accuracy_score(fil_review['label'],fil_review['pred_VADER'])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     190
#     191             try:
# --> 192                 return func(*args, **kwargs)
#     193             except InvalidParameterError as e:
#     194                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     219
#     220     # Compute accuracy for each possible representation
# --> 221     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
# ...
